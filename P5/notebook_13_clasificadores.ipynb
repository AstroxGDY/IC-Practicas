# %% [markdown]
# # Practica 5 - Sesion 3: Comparación de Clasificadores
#
# ## Ingeniería del Conocimiento    2025/2026
# ### Prof. Juan A. Recio García
#
# En esta práctica compararemos distintos clasificadores de **scikit-learn** y **XGBoost** sobre tres datasets con contextos muy diferentes. El objetivo central es entender que **la métrica de evaluación debe elegirse según el coste real de equivocarse**, no siempre la accuracy.
#
# ## Clasificadores a comparar
#
# | Clasificador | Clase sklearn |
# |---|---|
# | Logistic Regression | `LogisticRegression` |
# | Naive Bayes | `GaussianNB` |
# | K-Nearest Neighbors | `KNeighborsClassifier` |
# | SVM | `SVC` |
# | MLP (red neuronal) | `MLPClassifier` |
# | Random Forest | `RandomForestClassifier` |
# | XGBoost | `XGBClassifier` |
#
#
# ## Datasets y métricas
#
# | # | Dataset | Dominio | Métrica principal | Justificación |
# |---|---|---|---|---|
# | 1 | **Credit Card Fraud** | Finanzas | **F1-score** | Clases muy desbalanceadas; accuracy sería engañosa |
# | 2 | **Wisconsin Breast Cancer** | Medicina | **Recall** | Minimizar falsos negativos: no dejar cáncer sin detectar |
# | 3 | **Stock Movement** | Bolsa | **Precision** | Solo operar cuando la predicción es muy fiable |
#
# ---
#
# **El Dataset 1 (Credit Card Fraud) está resuelto como ejemplo.**
# Para los datasets 2 y 3 debéis replicar la misma estructura rellenando las celdas marcadas con `# TODO`.

# %% [markdown]
# ---
# ## 0. Imports y configuración general

# %%
# Posiblemente tendrás que instalar XGBoost para ejecutar este notebook ya que no se incluye en sklearn. Puedes hacerlo con:
# !pip install xgboost jinja2
# Out:
# Requirement already satisfied: xgboost in d:\IC\IC-Practicas\.venv\Lib\site-packages (3.2.0)
# Requirement already satisfied: jinja2 in d:\IC\IC-Practicas\.venv\Lib\site-packages (3.1.6)
# Requirement already satisfied: numpy in d:\IC\IC-Practicas\.venv\Lib\site-packages (from xgboost) (2.4.2)
# Requirement already satisfied: scipy in d:\IC\IC-Practicas\.venv\Lib\site-packages (from xgboost) (1.17.1)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\IC\IC-Practicas\.venv\Lib\site-packages (from jinja2) (3.0.3)
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# ── Librerías de análisis de datos ───────────────────────────────────────────
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ── Preprocesamiento ──────────────────────────────────────────────────────────
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_breast_cancer

# ── Clasificadores ────────────────────────────────────────────────────────────
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB           # Clasificador bayesiano probabilístico
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
import jinja2
from imblearn.over_sampling import SMOTE

# ── Métricas de evaluación ────────────────────────────────────────────────────
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, ConfusionMatrixDisplay, classification_report
)

# ── Configuración visual ──────────────────────────────────────────────────────
sns.set_theme(style='whitegrid')
plt.rcParams['figure.figsize'] = (10, 4)
import warnings
warnings.filterwarnings('ignore')  # Suprimimos warnings de convergencia durante la práctica

# %% [markdown]
# ### Funciones auxiliares reutilizables
# Definimos aquí las funciones que usaremos en los tres datasets para evitar repetir código.

# %%
def evaluar_clasificadores(X_train, X_test, y_train, y_test, highlight_metric='f1'):
    """
    Entrena los 7 clasificadores sobre los datos dados y devuelve una tabla con
    accuracy, precision, recall y F1. La columna highlight_metric aparece resaltada.
    """
    modelos = {
        'Logistic Regression' : LogisticRegression(max_iter=1000),
        'Naive Bayes'         : GaussianNB(),
        'KNN'                 : KNeighborsClassifier(n_neighbors=5),
        'SVM'                 : SVC(max_iter=100),
        'MLP'                 : MLPClassifier(hidden_layer_sizes=(50, 50), max_iter=100, random_state=42),
        'Random Forest'       : RandomForestClassifier(n_estimators=50, random_state=42),
        'XGBoost'             : XGBClassifier(eval_metric='logloss', random_state=42, verbosity=0),
    }

    resultados = []
    for nombre, modelo in modelos.items():
        print(f'Entrenando {nombre}...')
        modelo.fit(X_train, y_train)       # Entrenamos el modelo con los datos de entrenamiento
        y_pred = modelo.predict(X_test)    # Generamos predicciones sobre el conjunto de test
        resultados.append({
            'Modelo'    : nombre,
            'Accuracy'  : accuracy_score(y_test, y_pred),
            'Precision' : precision_score(y_test, y_pred, zero_division=0),
            'Recall'    : recall_score(y_test, y_pred, zero_division=0),
            'F1'        : f1_score(y_test, y_pred, zero_division=0),
        })

    col_map = {'precision': 'Precision', 'recall': 'Recall', 'f1': 'F1', 'accuracy': 'Accuracy'}
    col = col_map.get(highlight_metric, 'F1')
    df = pd.DataFrame(resultados).set_index('Modelo').sort_values(col, ascending=False)
    # Resaltamos en verde la columna relevante para que destaque visualmente
    return df.style.background_gradient(subset=[col], cmap='Greens').format('{:.4f}')


def mostrar_confusion(modelo, X_test, y_test, titulo='Matriz de Confusión'):
    """Muestra la matriz de confusión y el classification report de un modelo ya entrenado."""
    y_pred = modelo.predict(X_test)
    ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred)).plot(cmap='Blues')
    plt.title(titulo)
    plt.tight_layout()
    plt.show()
    print(classification_report(y_test, y_pred))
    print('Accuracy',  accuracy_score(y_test, y_pred))
    print('Precision', precision_score(y_test, y_pred, zero_division=0))
    print('Recall',    recall_score(y_test, y_pred, zero_division=0))
    print('F1',        f1_score(y_test, y_pred, zero_division=0))

# %% [markdown]
# ---
# # Dataset 1 — Credit Card Fraud *(Ejemplo resuelto)*
# ## Métrica principal: **F1-score**
#
# > **¿Por qué F1?**
# > El dataset está muy desbalanceado (~0.17% de fraudes). La *accuracy* sería engañosa:
# > un modelo que prediga siempre "no fraude" tendría >99% de accuracy pero no detectaría ningún fraude real.
# > El **F1** es la media armónica de Precision y Recall, ideal cuando las clases están desbalanceadas:
# >
# > $$F1 = 2 \cdot \frac{\text{Precision} \times \text{Recall}}{\text{Precision} + \text{Recall}}$$
#
# **Archivo:** `creditcard.csv`
# Fuente: [Kaggle - Credit Card Fraud Detection](https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud)

# %% [markdown]
# ### 1.1 Carga y exploración

# %%
# Las columnas V1-V28 son componentes PCA (anonimizadas por el banco)
# 'Amount' es el importe de la transacción; 'Class' es la etiqueta (1=fraude, 0=legítima)
df_fraud = pd.read_csv('creditcard.csv')

print(f'Shape: {df_fraud.shape}')
print(f'Valores nulos totales: {df_fraud.isnull().sum().sum()}')
df_fraud.head(3)
# Out:
# Shape: (284807, 31)
# Valores nulos totales: 0
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
#
# [3 rows x 31 columns]

# %%
# Analizamos el desbalance — esto justifica elegir F1 en vez de accuracy
conteo = df_fraud['Class'].value_counts()
print(f'Transacciones legítimas   : {conteo[0]:,}')
print(f'Transacciones fraudulentas: {conteo[1]:,}')
print(f'Porcentaje de fraude      : {100 * conteo[1] / len(df_fraud):.3f}%')
# Out:
# Transacciones legítimas   : 284,315
# Transacciones fraudulentas: 492
# Porcentaje de fraude      : 0.173%

# %% [markdown]
# ### 1.2 Preprocesamiento

# %%
# Eliminamos 'Time' (no aporta información útil) y separamos features de la variable objetivo
X_fraud = df_fraud.drop(columns=['Time', 'Class']).copy()
y_fraud = df_fraud['Class']

# Escalamos los datos. A
# Aunque los clasificadores basados en árboles no lo requieren, otros como SVM o MLP sí se benefician de tener las features en la misma escala.
# StandardScaler centra en media=0 y desviación estándar=1
scaler_fraud = StandardScaler()
X_fraud = scaler_fraud.fit_transform(X_fraud)

# Split estratificado: preserva el mismo porcentaje de fraudes (~0.17%) en train y test
X_train_f, X_test_f, y_train_f, y_test_f = train_test_split(
    X_fraud, y_fraud, test_size=0.2, random_state=42, stratify=y_fraud
)

print(f'Train: {X_train_f.shape} | Test: {X_test_f.shape}')
print(f'Fraudes en train: {y_train_f.sum()} | Fraudes en test: {y_test_f.sum()}')
# Out:
# Train: (227845, 29) | Test: (56962, 29)
# Fraudes en train: 394 | Fraudes en test: 98

# %% [markdown]
# ### 1.3 Entrenamiento y evaluación de clasificadores

# %%
# Entrenamos los 7 clasificadores y mostramos la tabla comparativa
# La columna F1 aparece resaltada porque es la métrica relevante para este problema
# SVM y MLP pueden tardar 1-2 minutos con datasets grandes
tabla_fraud = evaluar_clasificadores(X_train_f, X_test_f, y_train_f, y_test_f, highlight_metric='f1')
tabla_fraud
# Out:
# Entrenando Logistic Regression...
# Entrenando Naive Bayes...
# Entrenando KNN...
# Entrenando SVM...
# Entrenando MLP...
# Entrenando Random Forest...
# Entrenando XGBoost...
# <style type="text/css">
# #T_23f56_row0_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_23f56_row1_col3 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_23f56_row2_col3 {
#   background-color: #005522;
#   color: #f1f1f1;
# }
# #T_23f56_row3_col3 {
#   background-color: #005622;
#   color: #f1f1f1;
# }
# #T_23f56_row4_col3 {
#   background-color: #157f3b;
#   color: #f1f1f1;
# }
# #T_23f56_row5_col3 {
#   background-color: #3da65a;
#   color: #f1f1f1;
# }
# #T_23f56_row6_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_23f56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23f56_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_23f56_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_23f56_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_23f56_level0_col3" class="col_heading level0 col3" >F1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23f56_level0_row0" class="row_heading level0 row0" >Random Forest</th>
#       <td id="T_23f56_row0_col0" class="data row0 col0" >0.9996</td>
#       <td id="T_23f56_row0_col1" class="data row0 col1" >0.9524</td>
#       <td id="T_23f56_row0_col2" class="data row0 col2" >0.8163</td>
#       <td id="T_23f56_row0_col3" class="data row0 col3" >0.8791</td>
#     </tr>
#     <tr>
#       <th id="T_23f56_level0_row1" class="row_heading level0 row1" >KNN</th>
#       <td id="T_23f56_row1_col0" class="data row1 col0" >0.9996</td>
#       <td id="T_23f56_row1_col1" class="data row1 col1" >0.9294</td>
#       <td id="T_23f56_row1_col2" class="data row1 col2" >0.8061</td>
#       <td id="T_23f56_row1_col3" class="data row1 col3" >0.8634</td>
#     </tr>
#     <tr>
#       <th id="T_23f56_level0_row2" class="row_heading level0 row2" >MLP</th>
#       <td id="T_23f56_row2_col0" class="data row2 col0" >0.9994</td>
#       <td id="T_23f56_row2_col1" class="data row2 col1" >0.8300</td>
#       <td id="T_23f56_row2_col2" class="data row2 col2" >0.8469</td>
#       <td id="T_23f56_row2_col3" class="data row2 col3" >0.8384</td>
#     </tr>
#     <tr>
#       <th id="T_23f56_level0_row3" class="row_heading level0 row3" >XGBoost</th>
#       <td id="T_23f56_row3_col0" class="data row3 col0" >0.9995</td>
#       <td id="T_23f56_row3_col1" class="data row3 col1" >0.8764</td>
#       <td id="T_23f56_row3_col2" class="data row3 col2" >0.7959</td>
#       <td id="T_23f56_row3_col3" class="data row3 col3" >0.8342</td>
#     </tr>
#     <tr>
#       <th id="T_23f56_level0_row4" class="row_heading level0 row4" >Logistic Regression</th>
#       <td id="T_23f56_row4_col0" class="data row4 col0" >0.9992</td>
#       <td id="T_23f56_row4_col1" class="data row4 col1" >0.8289</td>
#       <td id="T_23f56_row4_col2" class="data row4 col2" >0.6429</td>
#       <td id="T_23f56_row4_col3" class="data row4 col3" >0.7241</td>
#     </tr>
#     <tr>
#       <th id="T_23f56_level0_row5" class="row_heading level0 row5" >SVM</th>
#       <td id="T_23f56_row5_col0" class="data row5 col0" >0.9989</td>
#       <td id="T_23f56_row5_col1" class="data row5 col1" >0.7869</td>
#       <td id="T_23f56_row5_col2" class="data row5 col2" >0.4898</td>
#       <td id="T_23f56_row5_col3" class="data row5 col3" >0.6038</td>
#     </tr>
#     <tr>
#       <th id="T_23f56_level0_row6" class="row_heading level0 row6" >Naive Bayes</th>
#       <td id="T_23f56_row6_col0" class="data row6 col0" >0.9764</td>
#       <td id="T_23f56_row6_col1" class="data row6 col1" >0.0587</td>
#       <td id="T_23f56_row6_col2" class="data row6 col2" >0.8469</td>
#       <td id="T_23f56_row6_col3" class="data row6 col3" >0.1099</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 1.4 Análisis del mejor modelo

# %%
# Entrenamos XGBoost para analizar en detalle (suele destacar en datos tabulares desbalanceados)
# Si en tu tabla un modelo diferente ha obtenido mejor F1, sustitúyelo aquí
# XGBoost cuenta con un parámetro muy útil que es scale_pos_weight. Con ello podemos intentar mejorar el recall sin sacrificar demasiado precision. Normalmente hay que probar con distintos valores hasta encontrar el que mejor se adapta a tu dataset. En este caso, con un valor de 0.50 hemos conseguido mejorar el recall sin sacrificar demasiado precision, lo que se traduce en una mejora del F1. 
mejor_f = RandomForestClassifier(n_estimators=100, random_state=42)
mejor_f.fit(X_train_f, y_train_f)

# La matriz de confusión muestra exactamente cuántos fraudes se detectan vs cuántos se pierden
mostrar_confusion(mejor_f, X_test_f, y_test_f,
                  titulo='Matriz de Confusión — XGBoost — Credit Card Fraud')
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.94      0.83      0.88        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.91      0.94     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Accuracy 0.9996137776061234
# Precision 0.9418604651162791
# Recall 0.826530612244898
# F1 0.8804347826086957

# %% [markdown]
# > Prueba con otros valores de scale_pos_weight
# >
# > No hemos usado XGBoost debido a que daba mejores resultados el Random Forest, por lo que el parámetro scale_pos_weight no aplica en este caso. Además este modelo ha tardado 3min en ejecutarse, así que probar con otros valores de este modelo no es muy eficiente.
# >
# > ¿Qué otra alternativa podríamos haber usado para evitar el desbalanceo?
# >
# > Para Random Forest, podríamos haber utilizado el parámetro class_weight='balanced' (o 'balanced_subsample'), que penaliza más los errores en la clase minoritaria. También podríamos haber aplicado SMOTE o RandomUnderSampler antes del entrenamiento.

# %%
# Eliminamos 'Time' (no aporta información útil) y separamos features de la variable objetivo
X_fraud = df_fraud.drop(columns=['Time', 'Class']).copy()
y_fraud = df_fraud['Class']

# Escalamos los datos. A
# Aunque los clasificadores basados en árboles no lo requieren, otros como SVM o MLP sí se benefician de tener las features en la misma escala.
# StandardScaler centra en media=0 y desviación estándar=1
scaler_fraud = StandardScaler()
X_fraud = scaler_fraud.fit_transform(X_fraud)

# Split estratificado: preserva el mismo porcentaje de fraudes (~0.17%) en train y test
X_train_f, X_test_f, y_train_f, y_test_f = train_test_split(
    X_fraud, y_fraud, test_size=0.2, random_state=42, stratify=y_fraud
)

smote = SMOTE(random_state=42)
X_train_f, y_train_f = smote.fit_resample(X_train_f, y_train_f)
y_train_f.value_counts()
# Out:
# Class
# 0    227451
# 1    227451
# Name: count, dtype: int64

# %%
# Cuidado, ahora tarda un buen rato porque hemos aumentado el número de muestras de fraude en el conjunto de entrenamiento. 
# Si quieres acelerar el proceso, puedes probar a reducir el número de árboles en Random Forest o XGBoost, además del número de iteraciones en SVM o MLP, o a entrenar solo un subconjunto de los clasificadores.
# o a entrenar solo un subconjunto de los clasificadores.
tabla_fraud = evaluar_clasificadores(X_train_f, X_test_f, y_train_f, y_test_f, highlight_metric='f1')
tabla_fraud
# Out:
# Entrenando Logistic Regression...
# Entrenando Naive Bayes...
# Entrenando KNN...
# Entrenando SVM...
# Entrenando MLP...
# Entrenando Random Forest...
# Entrenando XGBoost...
# <style type="text/css">
# #T_8dc72_row0_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_8dc72_row1_col3 {
#   background-color: #006328;
#   color: #f1f1f1;
# }
# #T_8dc72_row2_col3 {
#   background-color: #006428;
#   color: #f1f1f1;
# }
# #T_8dc72_row3_col3 {
#   background-color: #329b51;
#   color: #f1f1f1;
# }
# #T_8dc72_row4_col3, #T_8dc72_row5_col3 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_8dc72_row6_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_8dc72">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8dc72_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_8dc72_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_8dc72_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_8dc72_level0_col3" class="col_heading level0 col3" >F1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8dc72_level0_row0" class="row_heading level0 row0" >Random Forest</th>
#       <td id="T_8dc72_row0_col0" class="data row0 col0" >0.9995</td>
#       <td id="T_8dc72_row0_col1" class="data row0 col1" >0.8723</td>
#       <td id="T_8dc72_row0_col2" class="data row0 col2" >0.8367</td>
#       <td id="T_8dc72_row0_col3" class="data row0 col3" >0.8542</td>
#     </tr>
#     <tr>
#       <th id="T_8dc72_level0_row1" class="row_heading level0 row1" >MLP</th>
#       <td id="T_8dc72_row1_col0" class="data row1 col0" >0.9992</td>
#       <td id="T_8dc72_row1_col1" class="data row1 col1" >0.7193</td>
#       <td id="T_8dc72_row1_col2" class="data row1 col2" >0.8367</td>
#       <td id="T_8dc72_row1_col3" class="data row1 col3" >0.7736</td>
#     </tr>
#     <tr>
#       <th id="T_8dc72_level0_row2" class="row_heading level0 row2" >XGBoost</th>
#       <td id="T_8dc72_row2_col0" class="data row2 col0" >0.9991</td>
#       <td id="T_8dc72_row2_col1" class="data row2 col1" >0.7000</td>
#       <td id="T_8dc72_row2_col2" class="data row2 col2" >0.8571</td>
#       <td id="T_8dc72_row2_col3" class="data row2 col3" >0.7706</td>
#     </tr>
#     <tr>
#       <th id="T_8dc72_level0_row3" class="row_heading level0 row3" >KNN</th>
#       <td id="T_8dc72_row3_col0" class="data row3 col0" >0.9979</td>
#       <td id="T_8dc72_row3_col1" class="data row3 col1" >0.4410</td>
#       <td id="T_8dc72_row3_col2" class="data row3 col2" >0.8776</td>
#       <td id="T_8dc72_row3_col3" class="data row3 col3" >0.5870</td>
#     </tr>
#     <tr>
#       <th id="T_8dc72_level0_row4" class="row_heading level0 row4" >Logistic Regression</th>
#       <td id="T_8dc72_row4_col0" class="data row4 col0" >0.9732</td>
#       <td id="T_8dc72_row4_col1" class="data row4 col1" >0.0559</td>
#       <td id="T_8dc72_row4_col2" class="data row4 col2" >0.9184</td>
#       <td id="T_8dc72_row4_col3" class="data row4 col3" >0.1053</td>
#     </tr>
#     <tr>
#       <th id="T_8dc72_level0_row5" class="row_heading level0 row5" >Naive Bayes</th>
#       <td id="T_8dc72_row5_col0" class="data row5 col0" >0.9743</td>
#       <td id="T_8dc72_row5_col1" class="data row5 col1" >0.0559</td>
#       <td id="T_8dc72_row5_col2" class="data row5 col2" >0.8776</td>
#       <td id="T_8dc72_row5_col3" class="data row5 col3" >0.1051</td>
#     </tr>
#     <tr>
#       <th id="T_8dc72_level0_row6" class="row_heading level0 row6" >SVM</th>
#       <td id="T_8dc72_row6_col0" class="data row6 col0" >0.0131</td>
#       <td id="T_8dc72_row6_col1" class="data row6 col1" >0.0006</td>
#       <td id="T_8dc72_row6_col2" class="data row6 col2" >0.3571</td>
#       <td id="T_8dc72_row6_col3" class="data row6 col3" >0.0012</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 1.5 Conclusiones — Credit Card Fraud
# >
# > *Escribe aquí tus conclusiones:*
# >
# >- ¿Qué modelo obtiene el mejor F1 para detectar fraudes?
# >
# > El RandomForest obtiene el mejor F1
# >
# >- ¿Cómo se comporta la accuracy frente al F1? ¿Son coherentes?
# >
# > La accuracy es proporcional al F1, siempre que esta aumente, el F1 también aumentará. Es coherente ya que cuanto más preciso sea (más acierte sobre el total) mayor será la F1, mientras que si no acierta prácticamente nunca (caso SVM) pues la F1 tampoco acertará.
# >
# >- ¿Qué ocurriría si priorizáramos Recall sobre Precision en este contexto?
# >
# > El problema es que tendrían más en cuenta los falsos negativos, por lo que estarías priorizando a los minoritarios. Los falsos negativos son un grupo muy pequeño, por lo que la fórmula de recall daría valores muy "buenos" (casi 1) mientras que en realidad no se están detectando correctamente los fraudes. Por lo que estadísticamente es muy poco probable que el recall tenga valores bajos o poco precisos, la única forma de reducirlo sería si el accuracy es tan bajo que básicamente no detecta bien ni los positivos ni los negativos.
# >
# >- ¿Sirve de algo el oversampling? ¿Por qué?
# >
# > Sí, al haber más muestras de fraude el dataset está menos desbalanceado por lo que los resultados son más precisos.

# %% [markdown]
# ---
# # Dataset 2 — Wisconsin Breast Cancer  *(A completar)*
# ## Métrica principal: **Recall**
#
# > **¿Por qué Recall?**
# > En diagnóstico médico, un **falso negativo** (no detectar un cáncer real) es mucho más grave
# > que un falso positivo (hacer más pruebas a alguien sano). El Recall mide la proporción
# > de enfermos reales que el modelo es capaz de identificar:
# >
# > $$\text{Recall} = \frac{TP}{TP + FN}$$
#
# Fuente: [UCI ML Repository / sklearn.datasets.load_breast_cancer](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_breast_cancer.html)

# %% [markdown]
# ### 2.1 Carga y exploración

# %%
# sklearn incluye un dataset de cáncer de mama que es muy utilizado para practicar clasificación binaria. 
# Es un dataset limpio, sin valores nulos, con 569 muestras y 30 features numéricas extraídas de imágenes de tumores. 
# La variable objetivo es 'target', donde 0 indica tumores benignos y 1 indica tumores malignos. 
# TODO: Carga el dataset y analiza su contenido
# Muestra: shape, y distribución de clases (maligno=1 vs benigno=0)

# Carga el dataset
df_cancer = load_breast_cancer(as_frame=True).frame
df_cancer['target'] = 1 - df_cancer['target']

print(f'Shape: {df_cancer.shape}')
print(f'Valores nulos totales: {df_cancer.isnull().sum().sum()}')

# Analizamos la distribución de clases
conteo = df_cancer['target'].value_counts()
print(f'Tumores benignos (0): {conteo[0]}')
print(f'Tumores malignos (1): {conteo[1]}')
print(f'Porcentaje de tumores malignos frente benignos: {100 * conteo[1] / len(df_cancer):.2f}%')

# Mostramos las primeras filas
df_cancer.head(3)
# Out:
# Shape: (569, 31)
# Valores nulos totales: 0
# Tumores benignos (0): 357
# Tumores malignos (1): 212
# Porcentaje de tumores malignos frente benignos: 37.26%
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33            184.6      2019.0
# 1                 0.05667  ...          23.41            158.8      1956.0
# 2                 0.05999  ...          25.53            152.5      1709.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       1
# 1          0.2750                  0.08902       1
# 2          0.3613                  0.08758       1
#
# [3 rows x 31 columns]

# %% [markdown]
# ### 2.2 Preprocesamiento

# %%
# TODO: Separa X e y, aplica StandardScaler y realiza el split estratificado
# Recuerda: usa stratify=y para mantener la proporción de clases en train y test

X_cancer = df_cancer.drop(columns=['target']).copy()
y_cancer = df_cancer['target']

scaler_cancer = StandardScaler()
X_cancer_scaled = scaler_cancer.fit_transform(X_cancer)

X_train_c, X_test_c, y_train_c, y_test_c = train_test_split(
    X_cancer_scaled, y_cancer, test_size=0.2, random_state=42, stratify=y_cancer
)

print(f'Train: {X_train_c.shape} | Test: {X_test_c.shape}')
print(f'Casos malignos en train: {y_train_c.sum()} | Casos malignos en test: {y_test_c.sum()}')
# Out:
# Train: (455, 30) | Test: (114, 30)
# Casos malignos en train: 170 | Casos malignos en test: 42

# %% [markdown]
# ### 2.3 Entrenamiento y evaluación de clasificadores

# %%
# TODO: Llama a evaluar_clasificadores indicando recall como métrica principal

tabla_cancer = evaluar_clasificadores(X_train_c, X_test_c, y_train_c, y_test_c, highlight_metric='recall')
tabla_cancer
# Out:
# Entrenando Logistic Regression...
# Entrenando Naive Bayes...
# Entrenando KNN...
# Entrenando SVM...
# Entrenando MLP...
# Entrenando Random Forest...
# Entrenando XGBoost...
# <style type="text/css">
# #T_954d4_row0_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_954d4_row1_col2, #T_954d4_row2_col2, #T_954d4_row3_col2, #T_954d4_row4_col2 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_954d4_row5_col2 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_954d4_row6_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_954d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_954d4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_954d4_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_954d4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_954d4_level0_col3" class="col_heading level0 col3" >F1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_954d4_level0_row0" class="row_heading level0 row0" >MLP</th>
#       <td id="T_954d4_row0_col0" class="data row0 col0" >0.9825</td>
#       <td id="T_954d4_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_954d4_row0_col2" class="data row0 col2" >0.9524</td>
#       <td id="T_954d4_row0_col3" class="data row0 col3" >0.9756</td>
#     </tr>
#     <tr>
#       <th id="T_954d4_level0_row1" class="row_heading level0 row1" >SVM</th>
#       <td id="T_954d4_row1_col0" class="data row1 col0" >0.9649</td>
#       <td id="T_954d4_row1_col1" class="data row1 col1" >0.9750</td>
#       <td id="T_954d4_row1_col2" class="data row1 col2" >0.9286</td>
#       <td id="T_954d4_row1_col3" class="data row1 col3" >0.9512</td>
#     </tr>
#     <tr>
#       <th id="T_954d4_level0_row2" class="row_heading level0 row2" >Logistic Regression</th>
#       <td id="T_954d4_row2_col0" class="data row2 col0" >0.9649</td>
#       <td id="T_954d4_row2_col1" class="data row2 col1" >0.9750</td>
#       <td id="T_954d4_row2_col2" class="data row2 col2" >0.9286</td>
#       <td id="T_954d4_row2_col3" class="data row2 col3" >0.9512</td>
#     </tr>
#     <tr>
#       <th id="T_954d4_level0_row3" class="row_heading level0 row3" >Random Forest</th>
#       <td id="T_954d4_row3_col0" class="data row3 col0" >0.9737</td>
#       <td id="T_954d4_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_954d4_row3_col2" class="data row3 col2" >0.9286</td>
#       <td id="T_954d4_row3_col3" class="data row3 col3" >0.9630</td>
#     </tr>
#     <tr>
#       <th id="T_954d4_level0_row4" class="row_heading level0 row4" >XGBoost</th>
#       <td id="T_954d4_row4_col0" class="data row4 col0" >0.9737</td>
#       <td id="T_954d4_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_954d4_row4_col2" class="data row4 col2" >0.9286</td>
#       <td id="T_954d4_row4_col3" class="data row4 col3" >0.9630</td>
#     </tr>
#     <tr>
#       <th id="T_954d4_level0_row5" class="row_heading level0 row5" >KNN</th>
#       <td id="T_954d4_row5_col0" class="data row5 col0" >0.9561</td>
#       <td id="T_954d4_row5_col1" class="data row5 col1" >0.9744</td>
#       <td id="T_954d4_row5_col2" class="data row5 col2" >0.9048</td>
#       <td id="T_954d4_row5_col3" class="data row5 col3" >0.9383</td>
#     </tr>
#     <tr>
#       <th id="T_954d4_level0_row6" class="row_heading level0 row6" >Naive Bayes</th>
#       <td id="T_954d4_row6_col0" class="data row6 col0" >0.9211</td>
#       <td id="T_954d4_row6_col1" class="data row6 col1" >0.9231</td>
#       <td id="T_954d4_row6_col2" class="data row6 col2" >0.8571</td>
#       <td id="T_954d4_row6_col3" class="data row6 col3" >0.8889</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 2.4 Análisis del mejor modelo

# %%
# TODO: Instancia y entrena el modelo que haya obtenido mayor Recall
# Muestra su matriz de confusión con mostrar_confusion()

mejor_c = MLPClassifier(hidden_layer_sizes=(50, 50), max_iter=100, random_state=42)
mejor_c.fit(X_train_c, y_train_c)

mostrar_confusion(mejor_c, X_test_c, y_test_c, 
                  titulo='Matriz de Confusión — Logistic Regression (Balanced) — Breast Cancer')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        72
#            1       1.00      0.95      0.98        42
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Accuracy 0.9824561403508771
# Precision 1.0
# Recall 0.9523809523809523
# F1 0.975609756097561

# %% [markdown]
# ### 2.5 Conclusiones — Wisconsin Breast Cancer
#
# *Escribe aquí tus conclusiones:*
#
# - ¿Qué modelo maximiza el Recall?
# > El modelo MLP maximiza el Recall.
#
# - ¿Cuántos casos de cáncer quedan sin detectar (falsos negativos) con ese modelo?
# > Con el modelo MLP quedan sin detectar 2.
#
# - ¿Existe un trade-off entre Recall alto y Precision baja en algún modelo? ¿Es aceptable en este contexto?
# > No, no existe un trade-off.

# %% [markdown]
# ---
# # Dataset 3 — Stock Movement  *(A completar)*
# ## Métrica principal: **Precision**
#
# > **¿Por qué Precision?**
# > En predicción bursátil queremos operar **solo cuando el modelo está muy seguro** de que el precio subirá.
# > Un **falso positivo** (invertir cuando el precio baja) tiene coste económico directo.
# > La Precision mide cuántas de nuestras señales de compra son realmente correctas:
# >
# > $$\text{Precision} = \frac{TP}{TP + FP}$$
#
# 📂 **Archivo:** `stock_movement.csv`
# 📎 Target: `1` = el precio sube al día siguiente, `0` = baja o se mantiene.

# %% [markdown]
# ### 3.1 Carga y exploración

# %%
# TODO: Carga el dataset stock_movement.csv y analiza su contenido
# Muestra: shape, valores nulos, y distribución de clases (sube vs baja)

df_stock = pd.read_csv('stock_movement_small.csv')

print(f'Shape: {df_stock.shape}')
print(f'Valores nulos totales: {df_stock.isnull().sum().sum()}')

conteo = df_stock['target'].value_counts()
print(f'Días en que el precio baja o se mantiene (0): {conteo[0]}')
print(f'Días en que el precio sube (1)            : {conteo[1]}')
print(f'Porcentaje de subidas                     : {100 * conteo[1] / len(df_stock):.2f}%')

display(df_stock.head(3))
# Out:
# Shape: (146475, 15)
# Valores nulos totales: 0
# Días en que el precio baja o se mantiene (0): 75307
# Días en que el precio sube (1)            : 71168
# Porcentaje de subidas                     : 48.59%
#    return_1d  return_5d     sma_5    sma_20  price_sma5_ratio  \
# 0  -0.006214  -0.015543  32.08140  32.21560          0.997026
# 1  -0.035100  -0.179034   0.59364   0.70286          0.907621
# 2  -0.002581  -0.001763   8.86968   8.89742          1.002077
#
#    price_sma20_ratio  sma_cross  volatility_10  daily_range     rsi_14  \
# 0           0.992873   -0.13420       0.229769     0.015225  45.176110
# 1           0.766582   -0.10922       0.076357     0.109131  35.613372
# 2           0.998953   -0.02774       0.061752     0.008393  50.820715
#
#        macd  macd_signal  macd_hist  volume_ratio  target
# 0  0.032744     0.088844  -0.056100      0.583466       0
# 1 -0.151882    -0.160628   0.008746      0.624033       0
# 2 -0.042667    -0.049569   0.006903      0.531890       0

# %% [markdown]
# ### 3.2 Preprocesamiento

# %%
# TODO: Separa X e y, aplica StandardScaler y realiza el split
#
# 💡 Reflexión importante: los datos de bolsa son una serie temporal.
# Un split aleatorio mezclaría datos del futuro con el pasado (data leakage).
# En series temporales se usa shuffle=False para respetar el orden cronológico.

X_stock = df_stock.drop(columns=['target']).copy()
y_stock = df_stock['target']

scaler_stock = StandardScaler()
X_stock_scaled = scaler_stock.fit_transform(X_stock)

X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(
    X_stock_scaled, y_stock, test_size=0.2, shuffle=False
)

print(f'Train: {X_train_s.shape} | Test: {X_test_s.shape}')
print(f'Subidas en train: {y_train_s.sum()} | Subidas en test: {y_test_s.sum()}')
# Out:
# Train: (117180, 14) | Test: (29295, 14)
# Subidas en train: 56861 | Subidas en test: 14307

# %% [markdown]
# ### 3.3 Entrenamiento y evaluación de clasificadores

# %%
# TODO: Llama a evaluar_clasificadores indicando precision como métrica principal

tabla_stock = evaluar_clasificadores(X_train_s, X_test_s, y_train_s, y_test_s, highlight_metric='precision')
tabla_stock
# Out:
# Entrenando Logistic Regression...
# Entrenando Naive Bayes...
# Entrenando KNN...
# Entrenando SVM...
# Entrenando MLP...
# Entrenando Random Forest...
# Entrenando XGBoost...
# <style type="text/css">
# #T_75da2_row0_col1, #T_75da2_row1_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_75da2_row2_col1 {
#   background-color: #006729;
#   color: #f1f1f1;
# }
# #T_75da2_row3_col1 {
#   background-color: #026f2e;
#   color: #f1f1f1;
# }
# #T_75da2_row4_col1 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_75da2_row5_col1 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_75da2_row6_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_75da2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75da2_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_75da2_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_75da2_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_75da2_level0_col3" class="col_heading level0 col3" >F1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75da2_level0_row0" class="row_heading level0 row0" >XGBoost</th>
#       <td id="T_75da2_row0_col0" class="data row0 col0" >0.5174</td>
#       <td id="T_75da2_row0_col1" class="data row0 col1" >0.5065</td>
#       <td id="T_75da2_row0_col2" class="data row0 col2" >0.4583</td>
#       <td id="T_75da2_row0_col3" class="data row0 col3" >0.4812</td>
#     </tr>
#     <tr>
#       <th id="T_75da2_level0_row1" class="row_heading level0 row1" >MLP</th>
#       <td id="T_75da2_row1_col0" class="data row1 col0" >0.5171</td>
#       <td id="T_75da2_row1_col1" class="data row1 col1" >0.5064</td>
#       <td id="T_75da2_row1_col2" class="data row1 col2" >0.4407</td>
#       <td id="T_75da2_row1_col3" class="data row1 col3" >0.4713</td>
#     </tr>
#     <tr>
#       <th id="T_75da2_level0_row2" class="row_heading level0 row2" >Logistic Regression</th>
#       <td id="T_75da2_row2_col0" class="data row2 col0" >0.5130</td>
#       <td id="T_75da2_row2_col1" class="data row2 col1" >0.5045</td>
#       <td id="T_75da2_row2_col2" class="data row2 col2" >0.1557</td>
#       <td id="T_75da2_row2_col3" class="data row2 col3" >0.2379</td>
#     </tr>
#     <tr>
#       <th id="T_75da2_level0_row3" class="row_heading level0 row3" >Random Forest</th>
#       <td id="T_75da2_row3_col0" class="data row3 col0" >0.5149</td>
#       <td id="T_75da2_row3_col1" class="data row3 col1" >0.5041</td>
#       <td id="T_75da2_row3_col2" class="data row3 col2" >0.4211</td>
#       <td id="T_75da2_row3_col3" class="data row3 col3" >0.4589</td>
#     </tr>
#     <tr>
#       <th id="T_75da2_level0_row4" class="row_heading level0 row4" >KNN</th>
#       <td id="T_75da2_row4_col0" class="data row4 col0" >0.5084</td>
#       <td id="T_75da2_row4_col1" class="data row4 col1" >0.4967</td>
#       <td id="T_75da2_row4_col2" class="data row4 col2" >0.4911</td>
#       <td id="T_75da2_row4_col3" class="data row4 col3" >0.4939</td>
#     </tr>
#     <tr>
#       <th id="T_75da2_level0_row5" class="row_heading level0 row5" >SVM</th>
#       <td id="T_75da2_row5_col0" class="data row5 col0" >0.4944</td>
#       <td id="T_75da2_row5_col1" class="data row5 col1" >0.4902</td>
#       <td id="T_75da2_row5_col2" class="data row5 col2" >0.8783</td>
#       <td id="T_75da2_row5_col3" class="data row5 col3" >0.6292</td>
#     </tr>
#     <tr>
#       <th id="T_75da2_level0_row6" class="row_heading level0 row6" >Naive Bayes</th>
#       <td id="T_75da2_row6_col0" class="data row6 col0" >0.4888</td>
#       <td id="T_75da2_row6_col1" class="data row6 col1" >0.4885</td>
#       <td id="T_75da2_row6_col2" class="data row6 col2" >0.9951</td>
#       <td id="T_75da2_row6_col3" class="data row6 col3" >0.6553</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.4 Análisis del mejor modelo

# %%
# TODO: Instancia y entrena el modelo que haya obtenido mayor Precision
# Muestra su matriz de confusión con mostrar_confusion()

mejor_s = XGBClassifier(eval_metric='logloss', random_state=42, verbosity=0)

mejor_s.fit(X_train_s, y_train_s)

mostrar_confusion(mejor_s, X_test_s, y_test_s, 
                  titulo='Matriz de Confusión — Mejor Modelo (Precision) — Stock Movement')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.57      0.55     14988
#            1       0.51      0.46      0.48     14307
#
#     accuracy                           0.52     29295
#    macro avg       0.52      0.52      0.52     29295
# weighted avg       0.52      0.52      0.52     29295
#
# Accuracy 0.517357910906298
# Precision 0.5064884906534837
# Recall 0.45830712238764243
# F1 0.48119473085531866

# %% [markdown]
# ### 3.5 Conclusiones — Stock Movement
#
# *Escribe aquí tus conclusiones:*
#
# >- ¿Qué modelo obtiene mayor Precision?
# > El XGBoost tiene mayor precisión
# >- ¿Qué ocurre con el Recall de ese modelo? ¿Es un problema en este contexto?
# > El recall es menos del 50%. No es un problema porque no nos importa si el modelo predice que va a bajar pero en realidad sube.
# >- ¿Podría el modelo estar sobreajustando? ¿Cómo lo detectarías?
# > Se detectaría si existe una diferencia drástica entre la alta precisión obtenida en el conjunto de entrenamiento y la obtenida en el de test, lo que indicaría que el modelo ha memorizado el ruido de los datos pasados en lugar de aprender patrones generalizables.

# %% [markdown]
# ---
# # Comparativa Global
#
# Completa la tabla resumen con los mejores resultados obtenidos en cada dataset.

# %%
# TODO: Rellena los valores con los resultados de tu ejecución
resumen = pd.DataFrame([
    {'Dataset': 'Credit Card Fraud', 'Métrica clave': 'F1',        'Mejor Modelo': 'Random Forest', 'Valor': 0.8542},
    {'Dataset': 'Breast Cancer',     'Métrica clave': 'Recall',    'Mejor Modelo': 'MLP', 'Valor': 0.9524},
    {'Dataset': 'Stock Movement',    'Métrica clave': 'Precision', 'Mejor Modelo': 'XGBoost', 'Valor': 0.5065},
])
resumen.style.background_gradient(subset=['Valor'], cmap='Greens').format({'Valor': '{:.4f}'})
# Out:
# <style type="text/css">
# #T_5a231_row0_col3 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_5a231_row1_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_5a231_row2_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_5a231">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a231_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_5a231_level0_col1" class="col_heading level0 col1" >Métrica clave</th>
#       <th id="T_5a231_level0_col2" class="col_heading level0 col2" >Mejor Modelo</th>
#       <th id="T_5a231_level0_col3" class="col_heading level0 col3" >Valor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a231_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a231_row0_col0" class="data row0 col0" >Credit Card Fraud</td>
#       <td id="T_5a231_row0_col1" class="data row0 col1" >F1</td>
#       <td id="T_5a231_row0_col2" class="data row0 col2" >Random Forest</td>
#       <td id="T_5a231_row0_col3" class="data row0 col3" >0.8542</td>
#     </tr>
#     <tr>
#       <th id="T_5a231_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5a231_row1_col0" class="data row1 col0" >Breast Cancer</td>
#       <td id="T_5a231_row1_col1" class="data row1 col1" >Recall</td>
#       <td id="T_5a231_row1_col2" class="data row1 col2" >MLP</td>
#       <td id="T_5a231_row1_col3" class="data row1 col3" >0.9524</td>
#     </tr>
#     <tr>
#       <th id="T_5a231_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5a231_row2_col0" class="data row2 col0" >Stock Movement</td>
#       <td id="T_5a231_row2_col1" class="data row2 col1" >Precision</td>
#       <td id="T_5a231_row2_col2" class="data row2 col2" >XGBoost</td>
#       <td id="T_5a231_row2_col3" class="data row2 col3" >0.5065</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Preguntas de reflexión final
#
# *Responde brevemente en esta celda:*
#
# **1.** ¿Existe un clasificador que gane en los tres datasets, o el mejor modelo depende siempre del problema?
# > El mejor modelo siempre depende del problema, ya que en algunos problemas es más importante el recall, o la precission o el F1 y cada modelo se centra en uno de estos.
#
# **2.** ¿Por qué la accuracy no es una buena métrica universal? Da un ejemplo concreto con uno de los tres datasets.
# > No es buena porque ignora el desbalanceo de clases. Por ejemplo, en el dataset de Credit Card Fraud, un modelo que prediga siempre "No Fraude" tendría un 99.83% de accuracy pero sería totalmente inútil al no detectar ni un solo fraude real.
#
# **3.** ¿Qué clasificadores han sido más lentos de entrenar? ¿Merece la pena el coste computacional extra?
# > Los más lentos han sido SVM y MLP (y Random Forest con el oversampling activado). El coste merece la pena solo si el incremento en la métrica clave justifica el tiempo invertido.
#
# **4.** En el contexto médico, si tuvieras que elegir entre estos dos modelos hipotéticos, ¿cuál elegirías y por qué?
#
# | Modelo | Recall | Precision |
# |---|---|---|
# | A | 0.99 | 0.60 |
# | B | 0.85 | 0.95 |
#
# >Elegiría el Modelo A. En medicina es preferible tener un Recall alto (0.99) para asegurar que casi ningún paciente enfermo se quede sin detectar, aunque eso suponga tener más falsos positivos (menor precisión) que luego se descartarán con pruebas adicionales.
